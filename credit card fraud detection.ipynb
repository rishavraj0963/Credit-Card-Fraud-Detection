# %% [markdown]
# ![Screenshot (221)_LI.jpg](data:image/jpeg;base64,...)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
# Loading the dataset to a Pandas dataframe
credit_card_data = pd.read_csv('/content/creditcard.csv')

# %%
#First 5 rows of the dataset
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
#Last 5 rows of the dataset
credit_card_data.tail()
# Out:
#       Time        V1        V2        V3        V4        V5        V6  \
# 1981  1524 -0.340622  1.132232  1.291494  0.062313  0.016387 -0.977070
# 1982  1525 -1.842696  1.740641  0.861526 -0.856315 -0.655376 -0.842786
# 1983  1525 -0.480693  0.646091  1.577264 -0.084411 -0.305958 -0.534739
# 1984  1525 -0.342132  1.091125  1.282729  0.068076 -0.022498 -0.996727
# 1985  1526 -0.854343  1.382948  1.278665  2.914727 -0.183139 -0.349329
#
#             V7        V8        V9  ...       V21       V22       V23  \
# 1981  0.723755 -0.074630 -0.396655  ... -0.262948 -0.688785 -0.010937
# 1982  0.198563  0.602764  0.455595  ... -0.213609 -0.400617  0.030013
# 1983  0.860346 -0.028569 -0.800705  ...  0.121681  0.175190  0.035986
# 1984  0.676304 -0.042250 -0.312036  ... -0.269850 -0.734148 -0.007354
# 1985  0.274566  0.435277 -1.576521  ...       NaN       NaN       NaN
#
#            V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
#Dataset information
credit_card_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1986 entries, 0 to 1985
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    1986 non-null   int64
#  1   V1      1986 non-null   float64
#  2   V2      1986 non-null   float64
#  3   V3      1986 non-null   float64
#  4   V4      1986 non-null   float64
#  5   V5      1986 non-null   float64
#  6   V6      1986 non-null   float64
#  7   V7      1986 non-null   float64
#  8   V8      1986 non-null   float64
#  9   V9      1986 non-null   float64
#  10  V10     1986 non-null   float64
#  11  V11     1986 non-null   float64
#  12  V12     1986 non-null   float64
#  13  V13     1986 non-null   float64
#  14  V14     1985 non-null   float64
#  15  V15     1985 non-null   float64
#  16  V16     1985 non-null   float64
#  17  V17     1985 non-null   float64
#  18  V18     1985 non-null   float64
#  19  V19     1985 non-null   float64
# ...

# %%
credit_card_data.hist(figsize=(20,15))
plt.show()

# %%
# Checking number of missing values in each column
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       1
# V15       1
# V16       1
# V17       1
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %% [markdown]
# No missing values present in dataset

# %%
# Distributation of Legit and Fraudulent transactions
credit_card_data['Class'].value_counts()
# Out:
# 0.0    1983
# 1.0       2
# Name: Class, dtype: int64

# %% [markdown]
# This dataset is highly unbalanced

# %% [markdown]
# 0 --> Normal Transactions
#
# 1 --> Fraudulent Transactions

# %%
# Seperating the values for analaysis
legit = credit_card_data[credit_card_data.Class == 0]
fraud = credit_card_data[credit_card_data.Class == 1]

# %%
# Shape of legit and fraud data(rows, column)
print(legit.shape)
print(fraud.shape)
# Out:
# (1983, 31)
# (2, 31)

# %%
# Statistical measures of the data
legit.Amount.describe()
# Out:
# count    1983.000000
# mean       68.404892
# std       241.572682
# min         0.000000
# 25%         4.950000
# 50%        15.090000
# 75%        63.285000
# max      7712.430000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count      2.000000
# mean     264.500000
# std      374.059487
# min        0.000000
# 25%      132.250000
# 50%      264.500000
# 75%      396.750000
# max      529.000000
# Name: Amount, dtype: float64

# %%
# Compare the values for both the transactions
credit_card_data.groupby('Class').mean()
# Out:
#              Time        V1        V2        V3        V4        V5        V6  \
# Class
# 0.0    760.974786 -0.281494  0.267200  0.848906  0.146804 -0.077904  0.051713
# 1.0    439.000000 -2.677884 -0.602658 -0.260694  3.143275  0.418809 -1.245684
#
#              V7        V8        V9  ...       V20       V21       V22  \
# Class                                ...
# 0.0    0.139533 -0.059771  0.014492  ...  0.056618 -0.012217 -0.144666
# 1.0   -1.105907  0.661932 -1.520521  ...  1.114625  0.589464  0.200214
#
#             V23       V24       V25       V26       V27       V28      Amount
# Class
# 0.0   -0.043548  0.013865  0.108318  0.049441  0.027220 -0.001966   68.404892
# 1.0    0.455377  0.013198  0.162159  0.016239  0.004186 -0.053756  264.500000
#
# [2 rows x 30 columns]

# %% [markdown]
# Under-Sampling

# %% [markdown]
# Build a sample dataset containing similar distribution of legit and fraudulent transaction

# %% [markdown]
# Number of Fraudulent data - 492

# %%
legit_sample = legit.sample(n=492)

# %% [markdown]
# concatenating two data set
#
#
# 1.   fraud - 492 rows
# 2.   legit_sample - 492 rows

# %%
new_dataset = pd.concat([legit_sample, fraud], axis=0)

# %% [markdown]
# axis=0 ---> Row-wise addition
#
# axis=1 ---> Column-wise addition

# %%
new_dataset.head()
# Out:
#       Time        V1        V2        V3        V4        V5        V6  \
# 1907  1470  1.077176  0.288088  1.398870  2.807201 -0.766720 -0.128994
# 1536  1205 -0.321860 -0.284640  0.507416 -2.698884  1.647445  3.735537
# 609    460 -0.735723  1.280291  1.113868  1.090774  0.565825  0.615339
# 854    649  1.295841 -0.165526 -0.867118 -0.524867  1.815713  3.450555
# 971    735 -1.247323  0.672032  3.536527  3.293509 -0.796919  1.831510
#
#             V7        V8        V9  ...       V21       V22       V23  \
# 1907 -0.317085  0.026006 -0.130626  ...  0.109338  0.485917 -0.078512
# 1536 -0.767620  1.039697 -0.760195  ...  0.319331  0.845771 -0.331105
# 609   0.572713  0.203275 -0.613854  ... -0.043854  0.188161 -0.345303
# 854  -0.794598  0.880087  0.169386  ... -0.044837 -0.242532 -0.037723
# 971  -0.913056  0.497591  0.440543  ...  0.195893  1.012281 -0.406073
#
#            V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
new_dataset.tail()
# Out:
#      Time        V1        V2        V3        V4        V5        V6  \
# 537   403  1.085214 -0.228464  0.774503  1.379282 -0.469900  0.765731
# 412   297  1.145614  0.004148  0.772422  0.916543 -0.568699 -0.281603
# 112    74  1.038370  0.127486  0.184456  1.109950  0.441699  0.945283
# 541   406 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623   472 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
#
#            V7        V8        V9  ...       V21       V22       V23  \
# 537 -0.589284  0.426976  0.865987  ... -0.069035  0.049995 -0.111814
# 412 -0.161752 -0.025480  0.479307  ... -0.046280  0.174420 -0.014831
# 112 -0.036715  0.350995  0.118950  ...  0.102520  0.605089  0.023092
# 541 -2.537387  1.391657 -2.770089  ...  0.517232 -0.035049 -0.465211
# 623  0.325574 -0.067794 -0.270953  ...  0.661696  0.435477  1.375966
#
#           V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
new_dataset['Class'].value_counts()
# Out:
# 0.0    492
# 1.0      2
# Name: Class, dtype: int64

# %% [markdown]
# Number of Legit transaction in new_dataset = Number of Fraudulent transaction in new_dataset

# %%
new_dataset.groupby('Class').mean()
# Out:
#              Time        V1        V2        V3        V4        V5        V6  \
# Class
# 0.0    759.880081 -0.275778  0.225294  0.871820  0.169046 -0.053879  0.063270
# 1.0    439.000000 -2.677884 -0.602658 -0.260694  3.143275  0.418809 -1.245684
#
#              V7        V8        V9  ...       V20       V21       V22  \
# Class                                ...
# 0.0    0.044102 -0.029759 -0.021304  ...  0.038838 -0.024528 -0.111117
# 1.0   -1.105907  0.661932 -1.520521  ...  1.114625  0.589464  0.200214
#
#             V23       V24       V25       V26       V27       V28     Amount
# Class
# 0.0   -0.051122 -0.009320  0.091539  0.061537  0.018971  0.001973   58.48628
# 1.0    0.455377  0.013198  0.162159  0.016239  0.004186 -0.053756  264.50000
#
# [2 rows x 30 columns]

# %% [markdown]
# Splitting the data into Features and Target
#
# where, Targets nothing but 0's and 1's &
#
# Features are  V1, V2, ..., V28

# %%
X = new_dataset.drop(columns='Class', axis=1)
Y = new_dataset['Class']

# %%
print(X)
# Out:
#       Time        V1        V2        V3        V4        V5        V6  \
# 1907  1470  1.077176  0.288088  1.398870  2.807201 -0.766720 -0.128994
# 1536  1205 -0.321860 -0.284640  0.507416 -2.698884  1.647445  3.735537
# 609    460 -0.735723  1.280291  1.113868  1.090774  0.565825  0.615339
# 854    649  1.295841 -0.165526 -0.867118 -0.524867  1.815713  3.450555
# 971    735 -1.247323  0.672032  3.536527  3.293509 -0.796919  1.831510
# ...    ...       ...       ...       ...       ...       ...       ...
# 537    403  1.085214 -0.228464  0.774503  1.379282 -0.469900  0.765731
# 412    297  1.145614  0.004148  0.772422  0.916543 -0.568699 -0.281603
# 112     74  1.038370  0.127486  0.184456  1.109950  0.441699  0.945283
# 541    406 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623    472 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
#
#             V7        V8        V9  ...       V20       V21       V22  \
# ...

# %%
print(Y)
# Out:
# 1907    0.0
# 1536    0.0
# 609     0.0
# 854     0.0
# 971     0.0
#        ...
# 537     0.0
# 412     0.0
# 112     0.0
# 541     1.0
# 623     1.0
# Name: Class, Length: 494, dtype: float64

# %% [markdown]
# Split the data into traning data & testing data

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# %%
print(X.shape, x_train.shape, x_test.shape)
# Out:
# (494, 30) (395, 30) (99, 30)

# %% [markdown]
# Model Training
#
# Logistic Regression

# %%
# Loading one instance of LogisticRegression to model.
model = LogisticRegression()

# %%
# Training the Logistic Regression Model with Training Data
model.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# LogisticRegression()

# %% [markdown]
# Model Evaluation through Accuracy Score

# %%
# Accuracy on training data
x_train_prediction = model.predict(x_train)
training_data_accuracy = accuracy_score(x_train_prediction, y_train)

# %%
print('Accuracy on training data - ', training_data_accuracy)
# Out:
# Accuracy on training data -  1.0

# %% [markdown]
# Our model can predict correctly for 93.5% out of 100% prediction

# %%
# Accuracy on testing data
x_test_prediction = model.predict(x_test)
testing_data_accuracy = accuracy_score(x_test_prediction, y_test)

# %%
print('Accuracy on testing data - ', testing_data_accuracy)
# Out:
# Accuracy on testing data -  0.98989898989899

# %% [markdown]
# Here, Approx.(Training Data) = Approx.(Testing Data) -->means our model performed very well
#
# But Two more possible situation are there
#
# 1.   Over Fitted - Very-High % of Training data & Veru_Low % of Testing data
# 2.   Under Fitted - Very-Low % of Training data & Veru_High % of Testing data
